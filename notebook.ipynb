# %%
#describe, 
# info ,
#  find null values,
#  name of colums,
#  graph pie chart show fiction vs non fiction,
#  total year by year ratio of fiction and non fiction(bar chart or pie chart), 
# show best selling book ,
#  show how many time book appear,(bar) , 
# best seller book, author,(for both fiction and non fiction), in which yeaer whivh book or author is popular.
# author wise rating

# %%
import pandas as pd

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
booklist = pd.read_csv('dataset/bestsellers with categories.csv')

# %%
booklist
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
# [550 rows x 7 columns]

# %%
booklist.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
booklist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
booklist['Total'] = booklist.sum(axis=1)

# %%
booklist
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre  \
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# 2          Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3               George Orwell          4.7    21424      6  2017      Fiction
# 4    National Geographic Kids          4.8     7665     12  2019  Non Fiction
# ..                        ...          ...      ...    ...   ...          ...
# 545               Jeff Kinney          4.9     9413      8  2019      Fiction
# 546               Jen Sincero          4.7    14331      8  2016  Non Fiction
# 547               Jen Sincero          4.7    14331      8  2017  Non Fiction
# 548               Jen Sincero          4.7    14331      8  2018  Non Fiction
# 549               Jen Sincero          4.7    14331      8  2019  Non Fiction
#
#        Total
# 0    19378.7
# 1     4089.6
# 2    21016.7
# 3    23451.7
# 4     9700.8
# ..       ...
# 545  11444.9
# 546  16359.7
# 547  16360.7
# 548  16361.7
# 549  16362.7
#
# [550 rows x 8 columns]

# %%
#t_genre = booklist.groupby('Genre').sum()
#t_genre

# %% [markdown]
# # No of fiction Vs No of Non fiction books

# %%
t_genre = booklist.groupby('Genre').count()
t_genre
# Out:
#              Name  Author  User Rating  Reviews  Price  Year
# Genre
# Fiction       240     240          240      240    240   240
# Non Fiction   310     310          310      310    310   310

# %%
# Fiction Vs Non fIction book
plt.title('Number of Fiction Vs Non Fiction Books', y=1.15) 

plt.axis('equal') 

# add legend
plt.legend(labels=t_genre.index, loc='upper left')


t_genre['Total'].plot(kind = 'pie',figsize =(8,5),autopct='%.0f%%',startangle=90,shadow=True)
plt.show()

# %% [markdown]
# # BOOKS PUBLISHED IN ONE YEAR

# %% [markdown]
# # Fiction

# %%
fic = booklist[booklist['Genre']=='Fiction']
fic
# Out:
#                                                   Name               Author  \
# 1                                    11/22/63: A Novel         Stephen King
# 3                               1984 (Signet Classics)        George Orwell
# 5        A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6    A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                       A Gentleman in Moscow: A Novel          Amor Towles
# ..                                                 ...                  ...
# 541                                             Wonder        R. J. Palacio
# 542                                             Wonder        R. J. Palacio
# 543                                             Wonder        R. J. Palacio
# 544                                             Wonder        R. J. Palacio
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)          Jeff Kinney
#
#      User Rating  Reviews  Price  Year    Genre    Total
# 1            4.6     2052     22  2011  Fiction   4089.6
# 3            4.7    21424      6  2017  Fiction  23451.7
# 5            4.4    12643     11  2011  Fiction  14669.4
# 6            4.7    19735     30  2014  Fiction  21783.7
# 7            4.7    19699     15  2017  Fiction  21735.7
# ..           ...      ...    ...   ...      ...      ...
# 541          4.8    21625      9  2014  Fiction  23652.8
# 542          4.8    21625      9  2015  Fiction  23653.8
# 543          4.8    21625      9  2016  Fiction  23654.8
# 544          4.8    21625      9  2017  Fiction  23655.8
# 545          4.9     9413      8  2019  Fiction  11444.9
#
# [240 rows x 8 columns]

# %%
fic_year = fic[['Genre', 'Year']].groupby('Year').count()
fic_year
# Out:
#       Genre
# Year
# 2009     24
# 2010     20
# 2011     21
# 2012     21
# 2013     24
# 2014     29
# 2015     17
# 2016     19
# 2017     24
# 2018     21
# 2019     20

# %%
fic_year.plot(kind = 'bar', figsize= (14,5))
plt.ylabel('No of Fiction Books Published') # add to x-label to the plot
plt.xlabel('Year of Book Published') # add y-label to the plot
plt.title('Number of Fiction book published in one year') # add title to the plot

plt.show()

# %% [markdown]
# # Non Fiction

# %%
n_fic = booklist[booklist['Genre']== 'Non Fiction']
n_fic.head()
# Out:
#                                                  Name  \
# 0                       10-Day Green Smoothie Cleanse
# 2             12 Rules for Life: An Antidote to Chaos
# 4   5,000 Awesome Facts (About Everything!) (Natio...
# 8       A Higher Loyalty: Truth, Lies, and Leadership
# 11  A Patriot's History of the United States: From...
#
#                       Author  User Rating  Reviews  Price  Year        Genre  \
# 0                   JJ Smith          4.7    17350      8  2016  Non Fiction
# 2         Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 4   National Geographic Kids          4.8     7665     12  2019  Non Fiction
# 8                James Comey          4.7     5983      3  2018  Non Fiction
# 11          Larry Schweikart          4.6      460      2  2010  Non Fiction
#
#       Total
# 0   19378.7
# 2   21016.7
# 4    9700.8
# 8    8008.7
# 11   2476.6

# %%
n_fic_year = n_fic[['Genre','Year']].groupby('Year').count()
n_fic_year
# Out:
#       Genre
# Year
# 2009     26
# 2010     30
# 2011     29
# 2012     29
# 2013     26
# 2014     21
# 2015     33
# 2016     31
# 2017     26
# 2018     29
# 2019     30

# %%
n_fic_year.plot(kind = 'bar', figsize= (14,5))
plt.ylabel('No of Fiction Books Published') # add to x-label to the plot
plt.xlabel('Year of Book Published') # add y-label to the plot
plt.title('Number of Fiction book published in one year') # add title to the plot

plt.show()

# %%
n_fic_year.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # No of books published by an author

# %%
auth = booklist[['Name','Author']].groupby('Author').count()
auth.head(50)
# Out:
#                                     Name
# Author
# Abraham Verghese                       2
# Adam Gasiewski                         1
# Adam Mansbach                          1
# Adir Levy                              1
# Admiral William H. McRaven             1
# Adult Coloring Book Designs            1
# Alan Moore                             1
# Alex Michaelides                       1
# Alice Schertle                         1
# Allie Brosh                            1
# American Psychiatric Association       2
# American Psychological Association    10
# Amor Towles                            1
# Amy Ramos                              2
# Amy Shields                            1
# Andy Weir                              1
# Angie Grace                            1
# Angie Thomas                           1
# Ann Voskamp                            2
# Ann Whitford Paul                      2
# Anthony Bourdain                       1
# Anthony Doerr                          2
# Atul Gawande                           1
# Audrey Niffenegger                     1
# B. J. Novak                            2
# Bessel van der Kolk M.D.               1
# Bill Martin Jr.                        2
# Bill O'Reilly                          7
# Bill Simmons                           1
# Blue Star Coloring                     2
# Bob Woodward                           1
# Brandon Stanton                        3
# Brené Brown                           1
# Brian Kilmeade                         1
# Bruce Springsteen                      1
# Carol S. Dweck                         3
# Celeste Ng                             1
# Charlaine Harris                       4
# Charles Duhigg                         1
# Charles Krauthammer                    1
# Cheryl Strayed                         1
# Chip Gaines                            1
# Chip Heath                             1
# Chris Cleave                           1
# Chris Kyle                             1
# Chrissy Teigen                         1
# Christina Baker Kline                  1
# Christopher Paolini                    1
# Coloring Books for Adults              1
# Craig Smith                            2

# %%
auth.head(50).plot(kind = 'bar', figsize= (20,7))
plt.ylabel('No of Books')
plt.title('Number of Books Published By an Author')
# Out:
# Text(0.5, 1.0, 'Number of Books Published By an Author')

# %% [markdown]
# # Author wise Rating

# %%
auth_rate = booklist[['Author', 'User Rating']].groupby('Author').count()
auth_rate

# %%
sort_auth_rate = auth_rate.sort_values('User Rating', ascending= False)
sort_auth_rate
# Out:
#                                     User Rating
# Author
# Jeff Kinney                                  12
# Gary Chapman                                 11
# Suzanne Collins                              11
# Rick Riordan                                 11
# American Psychological Association           10
# ...                                         ...
# David Grann                                   1
# Larry Schweikart                              1
# David McCullough                              1
# Khaled Hosseini                               1
# Muriel Barbery                                1
#
# [248 rows x 1 columns]

# %%
sort_auth_rate.head(20).plot(kind = 'bar', figsize = (10,7))
# Out:
# <AxesSubplot:xlabel='Author'>

# %%
booklist[['User Rating']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'User Rating'}>]], dtype=object)

# %%
price_rate = booklist[['Price','User Rating']].groupby('Price').count()

# %%
price_rate.head()
# Out:
#        User Rating
# Price
# 0               12
# 1                1
# 2                5
# 3                1
# 4               32

# %%
plt.scatter(booklist['Price'], booklist['User Rating'])
plt.show()

# %%
#years = booklist['Year'].unique()
#years
# Out:
# array([2016, 2011, 2018, 2017, 2019, 2014, 2010, 2009, 2015, 2013, 2012],
#       dtype=int64)

# %%
#t_year = booklist['Year'].count()
#t_year
# Out:
# 550

# %%
#fic.head()
# Out:
#                                                 Name               Author  \
# 1                                  11/22/63: A Novel         Stephen King
# 3                             1984 (Signet Classics)        George Orwell
# 5      A Dance with Dragons (A Song of Ice and Fire)  George R. R. Martin
# 6  A Game of Thrones / A Clash of Kings / A Storm...  George R. R. Martin
# 7                     A Gentleman in Moscow: A Novel          Amor Towles
#
#    User Rating  Reviews  Price  Year    Genre
# 1          4.6     2052     22  2011  Fiction
# 3          4.7    21424      6  2017  Fiction
# 5          4.4    12643     11  2011  Fiction
# 6          4.7    19735     30  2014  Fiction
# 7          4.7    19699     15  2017  Fiction

# %%
#df = fic.groupby('Year').count()
#df
# Out:
#       Name  Author  User Rating  Reviews  Price  Genre
# Year
# 2009    24      24           24       24     24     24
# 2010    20      20           20       20     20     20
# 2011    21      21           21       21     21     21
# 2012    21      21           21       21     21     21
# 2013    24      24           24       24     24     24
# 2014    29      29           29       29     29     29
# 2015    17      17           17       17     17     17
# 2016    19      19           19       19     19     19
# 2017    24      24           24       24     24     24
# 2018    21      21           21       21     21     21
# 2019    20      20           20       20     20     20

# %%
#years = list(range(2008,2020))
#years
# Out:
# [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
#fic1 = fic[fic['Genre']=='Fiction']
#df = fic1.groupby('Year')

# %%
#fic1 =  fic.groupby('Year')

# %%
# step 2: plot data
#fic1.plot(kind='bar', figsize=(20, 6))

#plt.xlabel('Year') # add to x-label to the plot
#plt.ylabel('Number of immigrants') # add y-label to the plot
#plt.title('Icelandic immigrants to Canada from 1980 to 2013') # add title to the plot

#plt.show()

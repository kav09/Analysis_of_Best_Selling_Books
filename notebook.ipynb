# %%
#describe, 
# info ,
#  find null values,
#  name of colums,
#  graph pie chart show fiction vs non fiction,
#  total year by year ratio of fiction and non fiction(bar chart or pie chart), 
# show best selling book ,
#  show how many time book appear,(bar) , 
# best seller book, author,(for both fiction and non fiction), in which yeaer whivh book or author is popular.
# author wise rating

# %%
import pandas as pd

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
booklist = pd.read_csv('dataset/bestsellers with categories.csv')

# %%
booklist.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
booklist.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
booklist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
# Data Cleaning

booklist.set_index('Name', inplace=True)

# %%
booklist['Total'] = booklist.sum(axis=1)

# %%
booklist
# Out:
#                                                                       Author  \
# Name
# 10-Day Green Smoothie Cleanse                                       JJ Smith
# 11/22/63: A Novel                                               Stephen King
# 12 Rules for Life: An Antidote to Chaos                   Jordan B. Peterson
# 1984 (Signet Classics)                                         George Orwell
# 5,000 Awesome Facts (About Everything!) (Nation...  National Geographic Kids
# ...                                                                      ...
# Wrecking Ball (Diary of a Wimpy Kid Book 14)                     Jeff Kinney
# You Are a Badass: How to Stop Doubting Your Gre...               Jen Sincero
# You Are a Badass: How to Stop Doubting Your Gre...               Jen Sincero
# You Are a Badass: How to Stop Doubting Your Gre...               Jen Sincero
# You Are a Badass: How to Stop Doubting Your Gre...               Jen Sincero
#
# ...

# %%
#t_genre = booklist.groupby('Genre').sum()
#t_genre

# %% [markdown]
# # No of fiction Vs No of Non fiction books

# %%
#t_genre = booklist.groupby('Genre').count()
#t_genre

# %%
# Fiction Vs Non fIction book
plt.title('Number of Fiction Vs Non Fiction Books', y=1.15) 

plt.axis('equal') 

# add legend
plt.legend(labels=t_genre.index, loc='upper left')


t_genre['Total'].plot(kind = 'pie')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-9d8f020222dd> in <module>
#       5
#       6 # add legend
# ----> 7 plt.legend(labels=t_genre.index, loc='upper left')
#       8
#       9
#
# NameError: name 't_genre' is not defined

# %%
p = booklist.groupby('Genre').count()['Price']
p.plot(kind = 'pie',figsize =(8,5),autopct='%.0f%%',startangle=90,shadow=True)

# %% [markdown]
# # BOOKS PUBLISHED IN YEAR

# %% [markdown]
# # Fiction

# %%
fic = booklist[booklist['Genre']=='Fiction']
fic
# Out:
#                                                                  Author  \
# Name
# 11/22/63: A Novel                                          Stephen King
# 1984 (Signet Classics)                                    George Orwell
# A Dance with Dragons (A Song of Ice and Fire)       George R. R. Martin
# A Game of Thrones / A Clash of Kings / A Storm ...  George R. R. Martin
# A Gentleman in Moscow: A Novel                              Amor Towles
# ...                                                                 ...
# Wonder                                                    R. J. Palacio
# Wonder                                                    R. J. Palacio
# Wonder                                                    R. J. Palacio
# Wonder                                                    R. J. Palacio
# Wrecking Ball (Diary of a Wimpy Kid Book 14)                Jeff Kinney
#
#                                                     User Rating  Reviews  \
# Name
# ...

# %%
# fic_year = fic[['Genre', 'Year']].groupby('Year').count()
# fic_year

fic_year = fic.groupby('Year').count()['Genre']

# %%
ficyer = fic.groupby('Year').mean()['User Rating'].plot(kind = 'bar')
ficyer
# Out:
# <AxesSubplot:xlabel='Year'>

# %%
fic_year.plot(kind = 'bar', figsize= (14,5))
plt.ylabel('No of Fiction Books Published') # add to x-label to the plot
plt.xlabel('Year of Book Published') # add y-label to the plot
plt.title('Number of Fiction book published in one year') # add title to the plot

plt.show()

# %% [markdown]
# # Non Fiction

# %%
n_fic = booklist[booklist['Genre']== 'Non Fiction']
n_fic.head()
# Out:
#                                                                       Author  \
# Name
# 10-Day Green Smoothie Cleanse                                       JJ Smith
# 12 Rules for Life: An Antidote to Chaos                   Jordan B. Peterson
# 5,000 Awesome Facts (About Everything!) (Nation...  National Geographic Kids
# A Higher Loyalty: Truth, Lies, and Leadership                    James Comey
# A Patriot's History of the United States: From ...          Larry Schweikart
#
#                                                     User Rating  Reviews  \
# Name
# 10-Day Green Smoothie Cleanse                               4.7    17350
# 12 Rules for Life: An Antidote to Chaos                     4.7    18979
# 5,000 Awesome Facts (About Everything!) (Nation...          4.8     7665
# A Higher Loyalty: Truth, Lies, and Leadership               4.7     5983
# A Patriot's History of the United States: From ...          4.6      460
#
# ...

# %%
#n_fic_year = n_fic[['Genre','Year']].groupby('Year').count()
n_fic_year = n_fic.groupby('Year').count()['Genre']
n_fic_year
# Out:
# Year
# 2009    26
# 2010    30
# 2011    29
# 2012    29
# 2013    26
# 2014    21
# 2015    33
# 2016    31
# 2017    26
# 2018    29
# 2019    30
# Name: Genre, dtype: int64

# %%
n_fic_year.plot(kind = 'bar', figsize= (14,5))
plt.ylabel('No of Fiction Books Published') # add to x-label to the plot
plt.xlabel('Year of Book Published') # add y-label to the plot
plt.title('Number of Fiction book published in one year') # add title to the plot

plt.show()

# %%
n_fic_year.plot()
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # Comparision of Fiction and Non Fiction per year

# %%
p = booklist.groupby('Genre').count()['Price']
p.plot(kind = 'bar',figsize =(8,5))
# Out:
# <AxesSubplot:xlabel='Genre'>

# %%
plt.bar(n_fic_year.index , n_fic_year.values)
plt.bar(fic_year.index , fic_year.values)
# Out:
# <BarContainer object of 11 artists>

# %%
#comp = fic.groupby('Year').count()
#comp

# %%
#comp.plot(kind ='bar')

# %% [markdown]
# # No of books published by an author

# %%
#sort_auth= auth.sort_values('Price',ascending = False)

# %%
#auth = booklist[['Name','Author']].groupby('Author').count()
auth = booklist.groupby('Author').count()['Price']
sort_auth = auth.head(50).sort_values(ascending = False)

# %%
sort_auth.plot(kind = 'bar', figsize= (20,7))
plt.ylabel('No of Books')
plt.title('Number of Books Published By an Author')
# Out:
# Text(0.5, 1.0, 'Number of Books Published By an Author')

# %% [markdown]
# # Price

# %%
#n_fic[n_fic['Author']]['Price'].sort_values(ascending=False).plot()
name_price = n_fic.groupby('Name').head(10).sort_values('Price', ascending=False)
name_price
# Out:
#                                                                                 Author  \
# Name
# Diagnostic and Statistical Manual of Mental Dis...    American Psychiatric Association
# Diagnostic and Statistical Manual of Mental Dis...    American Psychiatric Association
# Hamilton: The Revolution                                            Lin-Manuel Miranda
# The Book of Basketball: The NBA According to Th...                        Bill Simmons
# Publication Manual of the American Psychologica...  American Psychological Association
# ...                                                                                ...
# A Higher Loyalty: Truth, Lies, and Leadership                              James Comey
# A Patriot's History of the United States: From ...                    Larry Schweikart
# Fear: Trump in the White House                                            Bob Woodward
# Eat This Not That! Supermarket Survival Guide: ...                     David Zinczenko
# ...

# %%
#name_price.groupby(name_price.index)['Price'].plot()
# Out:
# Name
# 10-Day Green Smoothie Cleanse                                                                     AxesSubplot(0.125,0.125;0.775x0.755)
# 12 Rules for Life: An Antidote to Chaos                                                           AxesSubplot(0.125,0.125;0.775x0.755)
# 5,000 Awesome Facts (About Everything!) (National Geographic Kids)                                AxesSubplot(0.125,0.125;0.775x0.755)
# A Higher Loyalty: Truth, Lies, and Leadership                                                     AxesSubplot(0.125,0.125;0.775x0.755)
# A Patriot's History of the United States: From Columbus's Great Discovery to the War on Terror    AxesSubplot(0.125,0.125;0.775x0.755)
#                                                                                                                   ...
# When Breath Becomes Air                                                                           AxesSubplot(0.125,0.125;0.775x0.755)
# ...

# %% [markdown]
# # Author wise Rating

# %%
# Count the rating
booklist['User Rating'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
#auth_rate = booklist[['Author', 'User Rating']].groupby('Author').mean()
auth_rate = booklist.groupby('Author').mean()['User Rating']

# %%
#sort_auth_rate = auth_rate.sort_values('User Rating', ascending= False)
auth_rate
# Out:
# Author
# Abraham Verghese              4.600000
# Adam Gasiewski                4.400000
# Adam Mansbach                 4.800000
# Adir Levy                     4.800000
# Admiral William H. McRaven    4.700000
#                                 ...
# Walter Isaacson               4.566667
# William Davis                 4.400000
# William P. Young              4.600000
# Wizards RPG Team              4.800000
# Zhi Gang Sha                  4.600000
# Name: User Rating, Length: 248, dtype: float64

# %%
auth_rate.head(100).plot(kind = 'line',figsize = (15,5))
# Out:
# <AxesSubplot:xlabel='Author'>

# %%
auth_rate.head(50).plot(kind = 'bar',figsize = (15,5))
# Out:
# <AxesSubplot:xlabel='Author'>

# %%
booklist[['User Rating','Price','Reviews']].hist()
# Out:
# array([[<AxesSubplot:title={'center':'User Rating'}>,
#         <AxesSubplot:title={'center':'Price'}>],
#        [<AxesSubplot:title={'center':'Reviews'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
booklist.groupby('Year').count()
# Out:
#       Author  User Rating  Reviews  Price  Genre  Total
# Year
# 2009      50           50       50     50     50     50
# 2010      50           50       50     50     50     50
# 2011      50           50       50     50     50     50
# 2012      50           50       50     50     50     50
# 2013      50           50       50     50     50     50
# 2014      50           50       50     50     50     50
# 2015      50           50       50     50     50     50
# 2016      50           50       50     50     50     50
# 2017      50           50       50     50     50     50
# 2018      50           50       50     50     50     50
# 2019      50           50       50     50     50     50

# %%
booklist["Year"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Price Vs Rating Scatter Plot or Trend Line

# %%
#price_rate = booklist[['Price','User Rating']].groupby('Price').count()
price_rate = booklist.groupby('Price').count()['User Rating']

# %%
price_rate.head()
# Out:
# Price
# 0    12
# 1     1
# 2     5
# 3     1
# 4    32
# Name: User Rating, dtype: int64

# %%
plt.scatter(booklist['Price'], booklist['User Rating'])
plt.show()

# %%
booklist.groupby('Name').mean().sort_values('Author',ascending=False).index
# Out:
# Index(['Zhi Gang Sha', 'Wizards RPG Team', 'William P. Young', 'William Davis',
#        'Walter Isaacson', 'W. Cleon Skousen', 'Veronica Roth',
#        'Tucker Carlson', 'Tony Hsieh', 'Todd Burpo',
#        ...
#        'Allie Brosh', 'Alice Schertle', 'Alex Michaelides', 'Alan Moore',
#        'Adult Coloring Book Designs', 'Admiral William H. McRaven',
#        'Adir Levy', 'Adam Mansbach', 'Adam Gasiewski', 'Abraham Verghese'],
#       dtype='object', name='Author', length=248)

# %%
#years = booklist['Year'].unique()
#years
# Out:
# array([2016, 2011, 2018, 2017, 2019, 2014, 2010, 2009, 2015, 2013, 2012],
#       dtype=int64)

# %%
#t_year = booklist['Year'].count()
#t_year
# Out:
# 550

# %%
#df = fic.groupby('Year').count()
#df

# %%
#years = list(range(2008,2020))
#years
# Out:
# [2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
#fic1 = fic[fic['Genre']=='Fiction']
#df = fic1.groupby('Year')

# %%
#fic1 =  fic.groupby('Year')

# %%
# step 2: plot data
#fic1.plot(kind='bar', figsize=(20, 6))

#plt.xlabel('Year') # add to x-label to the plot
#plt.ylabel('Number of immigrants') # add y-label to the plot
#plt.title('Icelandic immigrants to Canada from 1980 to 2013') # add title to the plot

#plt.show()

# %%
#booklist.groupby('Year').count()

# %% [markdown]
# # Authors

# %%
booklist['Author'].unique()

# %%
#booklist.Author.unique()
booklist[booklist['Author'] == 'Rick Riordan']['User Rating'].plot()
# Out:
# <AxesSubplot:>

# %%
booklist[booklist['Author'] == 'Rick Riordan']['User Rating'].plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
booklist.groupby('Author').count().sort_values('Total', ascending=False).head(10)
# Out:
#                                     User Rating  Reviews  Price  Year  Genre  \
# Author
# Jeff Kinney                                  12       12     12    12     12
# Gary Chapman                                 11       11     11    11     11
# Suzanne Collins                              11       11     11    11     11
# Rick Riordan                                 11       11     11    11     11
# American Psychological Association           10       10     10    10     10
# Gallup                                        9        9      9     9      9
# Dr. Seuss                                     9        9      9     9      9
# Rob Elliott                                   8        8      8     8      8
# Eric Carle                                    7        7      7     7      7
# Bill O'Reilly                                 7        7      7     7      7
#
#                                     Total
# Author
# Jeff Kinney                            12
# ...

# %%
booklist[booklist['Author']=='Jeff Kinney']['User Rating'].plot()
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
booklist[booklist['Author']== 'Jeff Kinney']['Price'].plot()
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
booklist[booklist['Author']== 'Gary Chapman']['User Rating'].plot()
# Out:
# <AxesSubplot:>

# %%
booklist[booklist['Author']=='Suzanne Collins']['User Rating'].plot()
# Out:
# <AxesSubplot:>

# %%
booklist[booklist['Author']=='Suzanne Collins']['User Rating'].plot(kind ="bar")
# Out:
# <AxesSubplot:>

# %%
booklist[booklist['Author']=='American Psychological Association']['User Rating'].plot()
# Out:
# <AxesSubplot:>

# %%
booklist[booklist['Author'] == 'Rick Riordan']['User Rating'].plot()
# Out:
# <AxesSubplot:xlabel='Name'>

# %% [markdown]
# # Reviews

# %%
booklist[booklist['Author']== 'Veronica Roth']['Reviews'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Name'>

# %%
# top rated author and review
booklist.groupby('Author').mean()['Reviews'].head(10).sort_values(ascending = False).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Author'>

# %%
# Author and its rating
booklist.groupby('Author').mean()['User Rating'].head(50).sort_values(ascending= False).plot()
# Out:
# <AxesSubplot:xlabel='Author'>

# %%
booklist.groupby('Author').count()['Reviews'].head(50).plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Author'>

# %%
booklist['Price'] = booklist['Price'].map(lambda price : price*75)

# %%
booklist['Price'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
booklist.describe()
# Out:
#        User Rating       Reviews        Price         Year         Total
# count   550.000000    550.000000   550.000000   550.000000    550.000000
# mean      4.618364  11953.281818   982.500000  2014.000000  13985.000182
# std       0.226980  11731.132017   813.169648     3.165156  11730.787025
# min       3.300000     37.000000     0.000000  2009.000000   2056.600000
# 25%       4.500000   4058.000000   525.000000  2011.000000   6082.225000
# 50%       4.700000   8580.000000   825.000000  2014.000000  10625.100000
# 75%       4.800000  17253.250000  1200.000000  2017.000000  19278.875000
# max       4.900000  87841.000000  7875.000000  2019.000000  89879.800000

# %%
list(booklist.index.unique())
# Out:
# ['10-Day Green Smoothie Cleanse',
#  '11/22/63: A Novel',
#  '12 Rules for Life: An Antidote to Chaos',
#  '1984 (Signet Classics)',
#  '5,000 Awesome Facts (About Everything!) (National Geographic Kids)',
#  'A Dance with Dragons (A Song of Ice and Fire)',
#  'A Game of Thrones / A Clash of Kings / A Storm of Swords / A Feast of Crows / A Dance with Dragons',
#  'A Gentleman in Moscow: A Novel',
#  'A Higher Loyalty: Truth, Lies, and Leadership',
#  'A Man Called Ove: A Novel',
#  "A Patriot's History of the United States: From Columbus's Great Discovery to the War on Terror",
#  'A Stolen Life: A Memoir',
#  'A Wrinkle in Time (Time Quintet)',
#  'Act Like a Lady, Think Like a Man: What Men Really Think About Love, Relationships, Intimacy, and Commitment',
#  'Adult Coloring Book Designs: Stress Relief Coloring Book: Garden Designs, Mandalas, Animals, and Paisley Patterns',
#  'Adult Coloring Book: Stress Relieving Animal Designs',
# ...

# %%
booklist['Price']
# Out:
# Name
# 10-Day Green Smoothie Cleanse                                                             253125000
# 11/22/63: A Novel                                                                         696093750
# 12 Rules for Life: An Antidote to Chaos                                                   474609375
# 1984 (Signet Classics)                                                                    189843750
# 5,000 Awesome Facts (About Everything!) (National Geographic Kids)                        379687500
#                                                                                             ...
# Wrecking Ball (Diary of a Wimpy Kid Book 14)                                              253125000
# You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life    253125000
# You Are a Badass: How to Stop Doubting Your Greatness and Start Living an Awesome Life    253125000
# ...

# %%
#booklist['Price'] = booklist['Price'].map(lambda price : price*75)
#booklist['Price'].head(50).sort_values(ascending = False)
# Out:
# Name
# A Stolen Life: A Memoir                                                                                                  1012500000
# A Game of Thrones / A Clash of Kings / A Storm of Swords / A Feast of Crows / A Dance with Dragons                        949218750
# Capital in the Twenty First Century                                                                                       885937500
# Barefoot Contessa Foolproof: Recipes You Can Trust: A Cookbook                                                            759375000
# 11/22/63: A Novel                                                                                                         696093750
# Barefoot Contessa, How Easy Is That?: Fabulous Recipes & Easy Tips                                                        664453125
# Born to Run                                                                                                               569531250
# ...

# %%
import seaborn as sns
sns.set_style('whitegrid')

# %%
books = booklist.groupby(['Year','Genre']).count().unstack()['Price']

# %%
books
# Out:
# Genre  Fiction  Non Fiction
# Year
# 2009        24           26
# 2010        20           30
# 2011        21           29
# 2012        21           29
# 2013        24           26
# 2014        29           21
# 2015        17           33
# 2016        19           31
# 2017        24           26
# 2018        21           29
# 2019        20           30

# %%
fig,axes=plt.subplots(2,2,figsize=(12,6))
sns.set_style('white')
axes.plot(books,markersize=5,markerfacecolor='grey',marker='o')
axes.set_title('Fiction Vs. Non Fiction Books In The Bestsellers List (2009-2019)',fontdict={'size':15})
plt.grid(0)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2752e1d59cde> in <module>
# ----> 1 fig,axes=plt.subplots(2,2,figsize=(12,6))
#       2 sns.set_style('white')
#       3 axes.plot(books,markersize=5,markerfacecolor='grey',marker='o')
#       4 axes.set_title('Fiction Vs. Non Fiction Books In The Bestsellers List (2009-2019)',fontdict={'size':15})
#       5 plt.grid(0)
#
# NameError: name 'plt' is not defined

# %%
booklist.groupby('Author').count().sort_values('Price' , ascending=False)[:20]
# Out:
#                                     User Rating  Reviews  Price  Year  Genre  \
# Author
# Jeff Kinney                                  12       12     12    12     12
# Gary Chapman                                 11       11     11    11     11
# Suzanne Collins                              11       11     11    11     11
# Rick Riordan                                 11       11     11    11     11
# American Psychological Association           10       10     10    10     10
# Gallup                                        9        9      9     9      9
# Dr. Seuss                                     9        9      9     9      9
# Rob Elliott                                   8        8      8     8      8
# Eric Carle                                    7        7      7     7      7
# Bill O'Reilly                                 7        7      7     7      7
# Dav Pilkey                                    7        7      7     7      7
# ...

# %% [markdown]
# # years

# %%
years = booklist['User Rating'].value_counts()
years
# Out:
# 4.8    127
# 4.7    108
# 4.6    105
# 4.5     60
# 4.9     52
# 4.4     38
# 4.3     25
# 4.0     14
# 4.2      8
# 4.1      6
# 3.9      3
# 3.8      2
# 3.3      1
# 3.6      1
# Name: User Rating, dtype: int64

# %%
year = booklist['Year'].value_counts()
year
# Out:
# 2019    50
# 2018    50
# 2017    50
# 2016    50
# 2015    50
# 2014    50
# 2013    50
# 2012    50
# 2011    50
# 2010    50
# 2009    50
# Name: Year, dtype: int64

# %%
booklist.groupby('Year').mean()['Reviews'].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Year'>
